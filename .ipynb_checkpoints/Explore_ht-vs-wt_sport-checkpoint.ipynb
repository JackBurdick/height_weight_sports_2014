# %% [markdown]
# # Viewing the data

# %%
# dependencies
# %matplotlib inline
import json
import numpy as np
import matplotlib.pyplot as plt

# %%
# config
JSONDATAPATH = './ht_wt_data_2014.json'

# %%
# load data from .json file
with open(JSONDATAPATH) as data_file:
    data = json.load(data_file)

# %%
# create list of attributes
attribute_list = []
for sport in data:
    for entry in data[sport]:
        for attribute in entry:
            if attribute not in attribute_list:
                attribute_list.append(attribute)

# %%
group_container = {}

# create dict for each outter level group
for group in data:
    group_container[group] = {}

for attribute in attribute_list:
    for group in data:
        cur_list = []
        for entry in data[group]:
            cur_list.append(int(entry[attribute]))
        group_container[group][attribute] = np.asarray(cur_list)
        
print(group_container)
# Out:
# {'nba': {'Weight': array([180, 180, 185, ..., 278, 263, 263]), 'Height': array([69, 69, 69, ..., 86, 87, 87])}, 'nhl': {'Weight': array([200, 200, 188, ..., 195, 180, 180]), 'Height': array([74, 74, 72, ..., 74, 71, 71])}, 'epl': {'Weight': array([168, 168, 154, ..., 165, 192, 192]), 'Height': array([70, 70, 71, ..., 70, 75, 75])}}

# %% [markdown]
# ## All data loaded loaded to dictionary;
# ```| data
# |
# |--|group
# |--|
# |--|--| height
# |--|--|--| {numpy array}
# |--|--| weight
# |--|--|--| {numpy array}```

# %%
# Peek at the data
for attribute in attribute_list:
    print(attribute)
    print("\t{0:<8s}{1:<8s}{2:<8s}".format("MIN","MEAN","MAX"))
    for group in group_container:
        print("{0:<5s} {min:5d} {mean:9.2f} {max:5d}".format(group, min=np.amin(group_container[group][attribute]), mean=np.mean(group_container[group][attribute]), max=np.amax(group_container[group][attribute])))
    print("\n")
# Out:
# Weight
# 	MIN     MEAN    MAX
# nba     157    220.67   290
# nhl     150    202.42   260
# epl     126    168.67   223
#
#
# Height
# 	MIN     MEAN    MAX
# nba      69     79.07    87
# nhl      65     73.26    81
# epl      63     71.74    80

# %%
# create histogram array
num_x = len(attribute_list)
num_y = len(group_container)

for attribute in attribute_list:
    fig, axes = plt.subplots(1, num_y, figsize=(14,2))
    fig.suptitle(attribute, fontsize=14, fontweight='bold')
    fig.subplots_adjust(top=.7)
    index = 0
    for group in group_container:
        axes[index].hist(group_container[group][attribute], normed=True)
        axes[index].set_title(group)
        if attribute == 'Height':
            axes[index].set_xlabel('in')
        if attribute == 'Weight':
            axes[index].set_xlabel('lbs')
        index += 1
    plt.show()

# %% [markdown]
# ### Overlay and scale the graphs

# %%
fig, axes = plt.subplots(1, num_x, figsize=(8,4))
for index, attribute in enumerate(attribute_list):
    for group in group_container:
        axes[index].hist(group_container[group][attribute], normed=True, label=group, histtype='stepfilled', alpha=0.7)
        if attribute == 'Height':
            axes[index].set_xlabel('in')
            axes[index].set_title('Height')
        if attribute == 'Weight':
            axes[index].set_xlabel('lbs')
            axes[index].set_title('Weight')
        axes[index].legend()

plt.show()

# %% [markdown]
# ### Lets view this another way

# %%
fig, axes = plt.subplots(1, num_x, figsize=(8,4))
for index, attribute in enumerate(attribute_list):
    plot_list = []
    for i, group in enumerate(group_container):
        plot_list.append(group_container[group][attribute])

    axes[index].boxplot(plot_list)
    axes[index].set_xticklabels(group_container)
    axes[index].set_title(attribute)

plt.show()

# %% [markdown]
# ### Height vs Weight

# %%
# first glance
fig, axes = plt.subplots(1, num_y, figsize=(14,4))
for i, group in enumerate(group_container):
    axes[i].scatter(group_container[group]['Weight'], group_container[group]['Height'])
    axes[i].set_title(group.upper())
    axes[i].set_ylabel('Height')
    axes[i].set_xlabel('Weight')
    # print(group_container[group]['Weight'])

# %% [markdown]
# ### Overlay and scale the graphs

# %%
fig, ax = plt.subplots(figsize=(8,8))
for i, group in enumerate(group_container):
    ax.scatter(group_container[group]['Weight'], group_container[group]['Height'], alpha=0.3, label=group.upper(), s=50)
    ax.legend()
    ax.set_ylabel('Height (in)')
    ax.set_xlabel('Weight (lbs)')
plt.show()
